# %%
import pandas as pd

# %%
people = {
    "first": ["Rohit", "Virat", "Jasprit", "Shubman", "Hardik", "Rishabh", "Suryakumar", "Ravindra", "Kuldeep", "Arshdeep", "Axar"],
    "last": ["Sharma", "Kohli", "Bumrah", "Gill", "Pandya", "Pant", "Yadav", "Jadeja", "Yadav", "Singh", "Patel"],
    "email": [
        "rohit.sharma@email.com", 
        "virat.kohli@email.com", 
        "jasprit.bumrah@email.com", 
        "shubman.gill@email.com", 
        "hardik.pandya@email.com", 
        "rishabh.pant@email.com", 
        "suryakumar.yadav@email.com", 
        "ravindra.jadeja@email.com", 
        "kuldeep.yadav@email.com", 
        "arshdeep.singh@email.com", 
        "axar.patel@email.com"
    ]
}

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#          first    last                       email
# 0        Rohit  Sharma      rohit.sharma@email.com
# 1        Virat   Kohli       virat.kohli@email.com
# 2      Jasprit  Bumrah    jasprit.bumrah@email.com
# 3      Shubman    Gill      shubman.gill@email.com
# 4       Hardik  Pandya     hardik.pandya@email.com
# 5      Rishabh    Pant      rishabh.pant@email.com
# 6   Suryakumar   Yadav  suryakumar.yadav@email.com
# 7     Ravindra  Jadeja   ravindra.jadeja@email.com
# 8      Kuldeep   Yadav     kuldeep.yadav@email.com
# 9     Arshdeep   Singh    arshdeep.singh@email.com
# 10        Axar   Patel        axar.patel@email.com

# %%
df['last'] == 'Doe'
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# Name: last, dtype: bool

# %%
filt = (df['last'] == 'Doe')

# %%
df[filt]
# Out:
# Empty DataFrame
# Columns: [first, last, email]
# Index: []

# %%
df[df['last'] == 'Yadav']
# Out:
#         first   last                       email
# 6  Suryakumar  Yadav  suryakumar.yadav@email.com
# 8     Kuldeep  Yadav     kuldeep.yadav@email.com

# %%
df.loc[filt]
# Out:
# Empty DataFrame
# Columns: [first, last, email]
# Index: []

# %%
df.loc[filt, 'email']
# Out:
# Series([], Name: email, dtype: str)

# %%
filt = (df['last'] == 'Yadav') & (df['first'] == 'Suryakumar')

# %%
df.loc[filt, 'email']
# Out:
# 6    suryakumar.yadav@email.com
# Name: email, dtype: str

# %%
filt = (df['last'] == 'Sharma') | (df['first'] == 'Rohit')

# %%
df.loc[filt, 'email']
# Out:
# 0    rohit.sharma@email.com
# Name: email, dtype: str

# %%
df.loc[~filt, 'email']
# Out:
# 1          virat.kohli@email.com
# 2       jasprit.bumrah@email.com
# 3         shubman.gill@email.com
# 4        hardik.pandya@email.com
# 5         rishabh.pant@email.com
# 6     suryakumar.yadav@email.com
# 7      ravindra.jadeja@email.com
# 8        kuldeep.yadav@email.com
# 9       arshdeep.singh@email.com
# 10          axar.patel@email.com
# Name: email, dtype: str

# %%
df = pd.read_csv('data/survey_results_public.csv', index_col='ResponseId')
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='qname')
# Out:
# /var/folders/y8/svf1rw9x0zs_d6z8j3nzm3sc0000gn/T/ipykernel_59717/3211394593.py:1: DtypeWarning: Columns (0: AIThreat, 1: DatabaseWantEntry, 2: DevEnvWantEntry, 3: SOTagsWant Entry, 4: OpSysPersonal use, 5: CommPlatformHaveWorkedWith, 6: CommPlatformWantEntr, 7: AIModelsChoice, 8: SOComm, 9: AIAgentOrchWrite, 10: AIAgentExternal) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/survey_results_public.csv', index_col='ResponseId')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.head(2)
# Out:
#                                 MainBranch              Age  \
# ResponseId
# 1           I am a developer by profession  25-34 years old
# 2           I am a developer by profession  25-34 years old
#
#                                                     EdLevel Employment  \
# ResponseId
# 1           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)   Employed
# 2                       Associate degree (A.A., A.S., etc.)   Employed
#
#                                              EmploymentAddl  WorkExp  \
# ResponseId
# 1           Caring for dependents (children, elderly, etc.)      8.0
# 2                                                       NaN      2.0
#
#                                               LearnCodeChoose  \
# ResponseId
# 1           Yes, I am not new to coding but am learning ne...
# 2           Yes, I am not new to coding but am learning ne...
#
#                                                     LearnCode  \
# ResponseId
# 1           Online Courses or Certification (includes all ...
# 2           Online Courses or Certification (includes all ...
#
#                                                   LearnCodeAI  \
# ResponseId
# 1           Yes, I learned how to use AI-enabled tools for...
# 2           Yes, I learned how to use AI-enabled tools for...
#
#                                      AILearnHow  YearsCode  \
# ResponseId
# 1           AI CodeGen tools or AI-enabled apps       14.0
# 2           AI CodeGen tools or AI-enabled apps       10.0
#
#                         DevType               OrgSize                  ICorPM  \
# ResponseId
# 1             Developer, mobile    20 to 99 employees          People manager
# 2           Developer, back-end  500 to 999 employees  Individual contributor
#
#                                                    RemoteWork  \
# ResponseId
# 1                                                      Remote
# 2           Hybrid (some in-person, leans heavy to flexibi...
#
#                                             PurchaseInfluence  \
# ResponseId
# 1           Yes, I influenced the purchase of a substantia...
# 2                                                          No
#
#             TechEndorseIntro  TechEndorse_1  TechEndorse_2  TechEndorse_3  \
# ResponseId
# 1                       Work           10.0            7.0            9.0
# 2           Personal Project           13.0            1.0            2.0
#
#             TechEndorse_4  TechEndorse_5  TechEndorse_6  TechEndorse_7  \
# ResponseId
# 1                     6.0            3.0           11.0           12.0
# 2                     9.0            4.0            3.0           12.0
#
#             TechEndorse_8  TechEndorse_9  TechEndorse_13 TechEndorse_13_TEXT  \
# ResponseId
# 1                     1.0            8.0            14.0                 NaN
# 2                     5.0            7.0            14.0                 NaN
#
#             TechOppose_1  TechOppose_2  TechOppose_3  TechOppose_5  \
# ResponseId
# 1                   15.0           7.0           8.0          12.0
# 2                   14.0           1.0          13.0          10.0
#
#             TechOppose_7  TechOppose_9  TechOppose_11  TechOppose_13  \
# ResponseId
# 1                   11.0           1.0            6.0           13.0
# 2                    9.0           3.0            4.0            2.0
#
#             TechOppose_16  TechOppose_15 TechOppose_15_TEXT  \
# ResponseId
# 1                     3.0           16.0                NaN
# 2                     5.0           15.0                NaN
#
#                                 Industry  JobSatPoints_1  JobSatPoints_2  ...  \
# ResponseId                                                                ...
# 1                                Fintech             3.0             1.0  ...
# 2           Retail and Consumer Services            10.0             8.0  ...
#
#             SO_Actions_10  SO_Actions_15  SO_Actions_15_TEXT         SOComm  \
# ResponseId
# 1                    11.0           15.0                 NaN        Neutral
# 2                    11.0           15.0                 NaN  Yes, somewhat
#
#                         SOFriction  \
# ResponseId
# 1             Rarely, almost never
# 2           About half of the time
#
#                                                AISelect       AISent  \
# ResponseId
# 1           Yes, I use AI tools monthly or infrequently  Indifferent
# 2                            Yes, I use AI tools weekly  Indifferent
#
#                                  AIAcc                      AIComplex  \
# ResponseId
# 1           Neither trust nor distrust  Bad at handling complex tasks
# 2           Neither trust nor distrust  Bad at handling complex tasks
#
#                                  AIToolCurrently partially AI  \
# ResponseId
# 1           Learning about a codebase;Writing code;Search ...
# 2                       Learning new concepts or technologies
#
#                      AIToolDon't plan to use AI for this task  \
# ResponseId
# 1           Project planning;Deployment and monitoring;Lea...
# 2           Learning about a codebase;Project planning;Com...
#
#                                AIToolPlan to partially use AI  \
# ResponseId
# 1           Documenting code;Debugging or fixing code;Test...
# 2           Writing code;Documenting code;Debugging or fix...
#
#             AIToolPlan to mostly use AI AIToolCurrently mostly AI  \
# ResponseId
# 1                                   NaN                       NaN
# 2                                   NaN                       NaN
#
#                                                 AIFrustration AIExplain  \
# ResponseId
# 1           AI solutions that are almost right, but not quite        No
# 2           AI solutions that are almost right, but not qu...        No
#
#                                                      AIAgents  \
# ResponseId
# 1           Yes, I use AI agents at work monthly or infreq...
# 2                                     No, and I don't plan to
#
#                       AIAgentChange          AIAgent_Uses AgentUsesGeneral  \
# ResponseId
# 1           Not at all or minimally  Software engineering              NaN
# 2           Not at all or minimally                   NaN              NaN
#
#                                   AIAgentImpactSomewhat agree  \
# ResponseId
# 1           AI agents have increased my productivity.;AI a...
# 2                                                         NaN
#
#                                          AIAgentImpactNeutral  \
# ResponseId
# 1           AI agents have helped me automate repetitive t...
# 2                                                         NaN
#
#            AIAgentImpactSomewhat disagree AIAgentImpactStrongly agree  \
# ResponseId
# 1                                     NaN                         NaN
# 2                                     NaN                         NaN
#
#            AIAgentImpactStrongly disagree  \
# ResponseId
# 1                                     NaN
# 2                                     NaN
#
#                                      AIAgentChallengesNeutral  \
# ResponseId
# 1           I am concerned about the accuracy of the infor...
# 2           It takes significant time and effort to learn ...
#
#                            AIAgentChallengesSomewhat disagree  \
# ResponseId
# 1           Integrating AI agents with my existing tools a...
# 2                                                         NaN
#
#                               AIAgentChallengesStrongly agree  \
# ResponseId
# 1           The cost of using certain AI agent platforms i...
# 2           I am concerned about the accuracy of the infor...
#
#                               AIAgentChallengesSomewhat agree  \
# ResponseId
# 1                                                         NaN
# 2           Integrating AI agents with my existing tools a...
#
#            AIAgentChallengesStrongly disagree AIAgentKnowledge  \
# ResponseId
# 1                                         NaN              NaN
# 2                                         NaN              NaN
#
#            AIAgentKnowWrite AIAgentOrchestration AIAgentOrchWrite  \
# ResponseId
# 1                       NaN            Vertex AI              NaN
# 2                       NaN                  NaN              NaN
#
#            AIAgentObserveSecure AIAgentObsWrite AIAgentExternal  \
# ResponseId
# 1                           NaN             NaN         ChatGPT
# 2                           NaN             NaN             NaN
#
#            AIAgentExtWrite                                            AIHuman  \
# ResponseId
# 1                      NaN                    When I don’t trust AI’s answers
# 2                      NaN  When I don’t trust AI’s answers;When I want to...
#
#                                            AIOpen ConvertedCompYearly JobSat
# ResponseId
# 1           Troubleshooting, profiling, debugging             61256.0   10.0
# 2                       All skills. AI is a flop.            104413.0    9.0
#
# [2 rows x 171 columns]

# %%
high_salary = (df['ConvertedCompYearly'] > 70000)

# %%
df.loc[high_salary]
# Out:
#                                                    MainBranch  \
# ResponseId
# 2                              I am a developer by profession
# 6                              I am a developer by profession
# 8                              I am a developer by profession
# 23                             I am a developer by profession
# 26                             I am a developer by profession
# ...                                                       ...
# 49067                          I am a developer by profession
# 49076                          I am a developer by profession
# 49084       I am not primarily a developer, but I write co...
# 49085       I am not primarily a developer, but I write co...
# 49089       I work with developers or my work supports dev...
#
#                         Age  \
# ResponseId
# 2           25-34 years old
# 6           45-54 years old
# 8           35-44 years old
# 23          25-34 years old
# 26          55-64 years old
# ...                     ...
# 49067       35-44 years old
# 49076       25-34 years old
# 49084       35-44 years old
# 49085       55-64 years old
# 49089       35-44 years old
#
#                                                       EdLevel  \
# ResponseId
# 2                         Associate degree (A.A., A.S., etc.)
# 6             Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 8              Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 23          Some college/university study without earning ...
# 26               Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                       ...
# 49067            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 49076         Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 49084            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 49085         Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 49089            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                    Employment  \
# ResponseId
# 2                                                    Employed
# 6           Independent contractor, freelancer, or self-em...
# 8                                                    Employed
# 23                                                   Employed
# 26          Independent contractor, freelancer, or self-em...
# ...                                                       ...
# 49067                                                Employed
# 49076                                                Employed
# 49084                                                Employed
# 49085                                            Not employed
# 49089                                                Employed
#
#                                                EmploymentAddl  WorkExp  \
# ResponseId
# 2                                                         NaN      2.0
# 6           Caring for dependents (children, elderly, etc....     15.0
# 8           Engaged in paid work (20-29 hours per week);Tr...     22.0
# 23                                          None of the above      7.0
# 26                                          None of the above     37.0
# ...                                                       ...      ...
# 49067         Caring for dependents (children, elderly, etc.)     19.0
# 49076                                       None of the above      4.0
# 49084                                       None of the above     22.0
# 49085                                       None of the above     46.0
# 49089                                       None of the above     15.0
#
#                                               LearnCodeChoose  \
# ResponseId
# 2           Yes, I am not new to coding but am learning ne...
# 6           Yes, I am not new to coding but am learning ne...
# 8           Yes, I am not new to coding but am learning ne...
# 23          Yes, I am not new to coding but am learning ne...
# 26          Yes, I am not new to coding but am learning ne...
# ...                                                       ...
# 49067       Yes, I am not new to coding but am learning ne...
# 49076       Yes, I am not new to coding but am learning ne...
# 49084       No, I am not new to coding and did not learn n...
# 49085       Yes, I am not new to coding but am learning ne...
# 49089       No, I am not new to coding and did not learn n...
#
#                                                     LearnCode  \
# ResponseId
# 2           Online Courses or Certification (includes all ...
# 6           Online Courses or Certification (includes all ...
# 8           Books / Physical media;Technical documentation...
# 23          Other online resources (e.g. standard search, ...
# 26          Stack Overflow or Stack Exchange;Technical doc...
# ...                                                       ...
# 49067       Online Courses or Certification (includes all ...
# 49076       Other online resources (e.g. standard search, ...
# 49084                                                     NaN
# 49085       Online Courses or Certification (includes all ...
# 49089                                                     NaN
#
#                                                   LearnCodeAI  \
# ResponseId
# 2           Yes, I learned how to use AI-enabled tools for...
# 6           Yes, I learned how to use AI-enabled tools req...
# 8           Yes, I learned how to use AI-enabled tools for...
# 23          Yes, I learned how to use AI-enabled tools req...
# 26          Yes, I learned how to use AI-enabled tools for...
# ...                                                       ...
# 49067       Yes, I learned how to use AI-enabled tools req...
# 49076       No, I learned something that was not related t...
# 49084       No, I didn't spend time learning in the past year
# 49085       No, I didn't spend time learning in the past year
# 49089       Yes, I learned how to use AI-enabled tools req...
#
#                                                    AILearnHow  YearsCode  \
# ResponseId
# 2                         AI CodeGen tools or AI-enabled apps       10.0
# 6           Technical documentation (is generated for/by t...       20.0
# 8           AI CodeGen tools or AI-enabled apps;Blogs or p...       30.0
# 23                           Colleague or on-the-job training       11.0
# 26          AI CodeGen tools or AI-enabled apps;Blogs or p...       41.0
# ...                                                       ...        ...
# 49067       AI CodeGen tools or AI-enabled apps;Other onli...       22.0
# 49076                                                     NaN       10.0
# 49084                                                     NaN        5.0
# 49085                                                     NaN        8.0
# 49089       AI CodeGen tools or AI-enabled apps;Blogs or p...       10.0
#
#                                      DevType                   OrgSize  \
# ResponseId
# 2                        Developer, back-end      500 to 999 employees
# 6                        Developer, back-end                       NaN
# 8           Architect, software or solutions    Less than 20 employees
# 23                     Developer, full-stack      100 to 499 employees
# 26                     Developer, full-stack                       NaN
# ...                                      ...                       ...
# 49067                  Developer, full-stack  5,000 to 9,999 employees
# 49076                  Developer, full-stack  1,000 to 4,999 employees
# 49084        DevOps engineer or professional  10,000 or more employees
# 49085                  Developer, QA or test                       NaN
# 49089                    Engineering manager      100 to 499 employees
#
#                             ICorPM  \
# ResponseId
# 2           Individual contributor
# 6                              NaN
# 8                   People manager
# 23          Individual contributor
# 26                             NaN
# ...                            ...
# 49067               People manager
# 49076       Individual contributor
# 49084       Individual contributor
# 49085                          NaN
# 49089               People manager
#
#                                                    RemoteWork  \
# ResponseId
# 2           Hybrid (some in-person, leans heavy to flexibi...
# 6                                                         NaN
# 8                                                      Remote
# 23                                                     Remote
# 26                                                        NaN
# ...                                                       ...
# 49067       Hybrid (some in-person, leans heavy to flexibi...
# 49076       Hybrid (some in-person, leans heavy to flexibi...
# 49084                                                  Remote
# 49085                                                     NaN
# 49089                                                  Remote
#
#                                             PurchaseInfluence  \
# ResponseId
# 2                                                          No
# 6           Yes, I influenced the purchase of a substantia...
# 8           Yes, I influenced the purchase of a substantia...
# 23          Yes, I influenced the purchase of a tool that ...
# 26          Yes, I influenced the purchase of a substantia...
# ...                                                       ...
# 49067       Yes, I influenced the purchase of a substantia...
# 49076                                                      No
# 49084                                                      No
# 49085                                                     NaN
# 49089       Yes, I influenced the purchase of a tool that ...
#
#             TechEndorseIntro  TechEndorse_1  TechEndorse_2  TechEndorse_3  \
# ResponseId
# 2           Personal Project           13.0            1.0            2.0
# 6                       Work           12.0            5.0            4.0
# 8           Personal Project           12.0            2.0            1.0
# 23                      Work           13.0            3.0            9.0
# 26          Personal Project            7.0            5.0            4.0
# ...                      ...            ...            ...            ...
# 49067                   Work            1.0            6.0            3.0
# 49076       Personal Project            9.0            1.0            6.0
# 49084                   Work            8.0            4.0            7.0
# 49085       Personal Project            9.0            3.0            6.0
# 49089                   Work            5.0            4.0            3.0
#
#             TechEndorse_4  TechEndorse_5  TechEndorse_6  TechEndorse_7  \
# ResponseId
# 2                     9.0            4.0            3.0           12.0
# 6                     6.0            2.0           10.0            3.0
# 8                    10.0            4.0            5.0            8.0
# 23                   10.0            1.0           11.0            4.0
# 26                    2.0            1.0            8.0            3.0
# ...                   ...            ...            ...            ...
# 49067                 7.0            5.0            2.0            8.0
# 49076                 3.0            2.0            8.0            7.0
# 49084                 9.0            1.0            6.0            2.0
# 49085                 4.0            5.0            2.0            8.0
# 49089                 7.0            1.0            9.0            8.0
#
#             TechEndorse_8  TechEndorse_9  TechEndorse_13 TechEndorse_13_TEXT  \
# ResponseId
# 2                     5.0            7.0            14.0                 NaN
# 6                     7.0            8.0            14.0                 NaN
# 8                     6.0            7.0            14.0                 NaN
# 23                    2.0            5.0            14.0                 NaN
# 26                    6.0           13.0            14.0                 NaN
# ...                   ...            ...             ...                 ...
# 49067                 9.0            4.0            10.0                 NaN
# 49076                 4.0            5.0            10.0                 NaN
# 49084                 5.0            3.0            10.0                 NaN
# 49085                 7.0            1.0            10.0                 NaN
# 49089                 6.0            2.0            10.0                 NaN
#
#             TechOppose_1  TechOppose_2  TechOppose_3  TechOppose_5  \
# ResponseId
# 2                   14.0           1.0          13.0          10.0
# 6                   12.0           5.0          13.0          10.0
# 8                   14.0           3.0           4.0           9.0
# 23                  14.0           2.0           8.0          12.0
# 26                  11.0           2.0           8.0           5.0
# ...                  ...           ...           ...           ...
# 49067                6.0           9.0           7.0           2.0
# 49076                5.0           2.0           9.0           8.0
# 49084                6.0           8.0           5.0           9.0
# 49085                7.0           5.0           9.0           8.0
# 49089                6.0           4.0           9.0           5.0
#
#             TechOppose_7  TechOppose_9  TechOppose_11  TechOppose_13  \
# ResponseId
# 2                    9.0           3.0            4.0            2.0
# 6                    9.0           1.0            4.0            6.0
# 8                    1.0           5.0            2.0           11.0
# 23                   4.0           1.0           13.0           10.0
# 26                   6.0           4.0            1.0            3.0
# ...                  ...           ...            ...            ...
# 49067                1.0           3.0            8.0            5.0
# 49076                1.0           7.0            4.0            3.0
# 49084                1.0           3.0            2.0            7.0
# 49085                3.0           1.0            6.0            2.0
# 49089                3.0           2.0            7.0            1.0
#
#             TechOppose_16  TechOppose_15 TechOppose_15_TEXT  \
# ResponseId
# 2                     5.0           15.0                NaN
# 6                     2.0           15.0                NaN
# 8                    12.0           15.0                NaN
# 23                    3.0           15.0                NaN
# 26                    9.0           15.0                NaN
# ...                   ...            ...                ...
# 49067                 4.0           10.0                NaN
# 49076                 6.0           10.0                NaN
# 49084                 4.0           10.0                NaN
# 49085                 4.0           10.0                NaN
# 49089                 8.0           10.0                NaN
#
#                                    Industry  JobSatPoints_1  JobSatPoints_2  \
# ResponseId
# 2              Retail and Consumer Services            10.0             8.0
# 6                                   Fintech             4.0             3.0
# 8                      Software Development             7.0             9.0
# 23                                  Fintech             3.0             2.0
# 26                     Software Development             2.0             1.0
# ...                                     ...             ...             ...
# 49067          Retail and Consumer Services            13.0             6.0
# 49076       Transportation, or Supply Chain             NaN             NaN
# 49084          Retail and Consumer Services             NaN             NaN
# 49085                                   NaN             NaN             NaN
# 49089                  Software Development             NaN             NaN
#
#             ...  SO_Actions_10  SO_Actions_15  SO_Actions_15_TEXT  \
# ResponseId  ...
# 2           ...           11.0           15.0                 NaN
# 6           ...           11.0           15.0                 NaN
# 8           ...           11.0           15.0                 NaN
# 23          ...            9.0           15.0                 NaN
# 26          ...           13.0           15.0                 NaN
# ...         ...            ...            ...                 ...
# 49067       ...            NaN            NaN                 NaN
# 49076       ...            NaN            NaN                 NaN
# 49084       ...            NaN            NaN                 NaN
# 49085       ...            8.0           10.0                 NaN
# 49089       ...            NaN            NaN                 NaN
#
#                      SOComm              SOFriction  \
# ResponseId
# 2             Yes, somewhat  About half of the time
# 6             Yes, somewhat    Rarely, almost never
# 8           Yes, definitely  About half of the time
# 23          Yes, definitely    Rarely, almost never
# 26            Yes, somewhat    Rarely, almost never
# ...                     ...                     ...
# 49067                   NaN                     NaN
# 49076                   NaN                     NaN
# 49084                   NaN                     NaN
# 49085        No, not really    Rarely, almost never
# 49089                   NaN                     NaN
#
#                                                AISelect          AISent  \
# ResponseId
# 2                            Yes, I use AI tools weekly     Indifferent
# 6                             Yes, I use AI tools daily     Indifferent
# 8                             Yes, I use AI tools daily  Very favorable
# 23          Yes, I use AI tools monthly or infrequently     Unfavorable
# 26                            Yes, I use AI tools daily       Favorable
# ...                                                 ...             ...
# 49067                         Yes, I use AI tools daily       Favorable
# 49076                        Yes, I use AI tools weekly       Favorable
# 49084                         Yes, I use AI tools daily       Favorable
# 49085                            No, but I plan to soon       Favorable
# 49089                                               NaN             NaN
#
#                                  AIAcc  \
# ResponseId
# 2           Neither trust nor distrust
# 6                    Somewhat distrust
# 8                       Somewhat trust
# 23                   Somewhat distrust
# 26          Neither trust nor distrust
# ...                                ...
# 49067                  Highly distrust
# 49076                Somewhat distrust
# 49084                     Highly trust
# 49085                   Somewhat trust
# 49089                              NaN
#
#                                                 AIComplex  \
# ResponseId
# 2                           Bad at handling complex tasks
# 6           Good, but not great at handling complex tasks
# 8           Neither good or bad at handling complex tasks
# 23                          Bad at handling complex tasks
# 26          Good, but not great at handling complex tasks
# ...                                                   ...
# 49067       Good, but not great at handling complex tasks
# 49076                       Bad at handling complex tasks
# 49084                       Bad at handling complex tasks
# 49085       Neither good or bad at handling complex tasks
# 49089                                                 NaN
#
#                                  AIToolCurrently partially AI  \
# ResponseId
# 2                       Learning new concepts or technologies
# 6           Learning about a codebase;Writing code;Documen...
# 8                               Writing code;Documenting code
# 23                                               Writing code
# 26          Learning about a codebase;Project planning;Wri...
# ...                                                       ...
# 49067       Debugging or fixing code;Testing code;Creating...
# 49076       Learning about a codebase;Writing code;Debuggi...
# 49084                                                     NaN
# 49085       Search for answers;Generating content or synth...
# 49089                                                     NaN
#
#                      AIToolDon't plan to use AI for this task  \
# ResponseId
# 2           Learning about a codebase;Project planning;Com...
# 6                                        Predictive analytics
# 8                                                         NaN
# 23          Learning about a codebase;Project planning;Doc...
# 26                                                        NaN
# ...                                                       ...
# 49067                                    Predictive analytics
# 49076                                                     NaN
# 49084                                                     NaN
# 49085       Project planning;Deployment and monitoring;Pre...
# 49089                                                     NaN
#
#                                AIToolPlan to partially use AI  \
# ResponseId
# 2           Writing code;Documenting code;Debugging or fix...
# 6                                   Deployment and monitoring
# 8           Project planning;Debugging or fixing code;Depl...
# 23          Debugging or fixing code;Creating or maintaini...
# 26                                                        NaN
# ...                                                       ...
# 49067       Project planning;Committing and reviewing code...
# 49076       Project planning;Documenting code;Testing code...
# 49084                                                     NaN
# 49085       Learning about a codebase;Writing code;Documen...
# 49089                                                     NaN
#
#                                   AIToolPlan to mostly use AI  \
# ResponseId
# 2                                                         NaN
# 6           Project planning;Debugging or fixing code;Comm...
# 8           Learning about a codebase;Testing code;Committ...
# 23                                       Predictive analytics
# 26                                                        NaN
# ...                                                       ...
# 49067       Learning about a codebase;Writing code;Documen...
# 49076                                                     NaN
# 49084                                                     NaN
# 49085                                                     NaN
# 49089                                                     NaN
#
#                                     AIToolCurrently mostly AI  \
# ResponseId
# 2                                                         NaN
# 6           Testing code;Learning new concepts or technolo...
# 8           Search for answers;Learning new concepts or te...
# 23                                                        NaN
# 26                                                        NaN
# ...                                                       ...
# 49067                                                     NaN
# 49076                                                     NaN
# 49084                                                     NaN
# 49085                                                     NaN
# 49089                                                     NaN
#
#                                                 AIFrustration  \
# ResponseId
# 2           AI solutions that are almost right, but not qu...
# 6           AI solutions that are almost right, but not quite
# 8           AI solutions that are almost right, but not qu...
# 23          AI solutions that are almost right, but not qu...
# 26          AI solutions that are almost right, but not quite
# ...                                                       ...
# 49067       AI solutions that are almost right, but not qu...
# 49076       AI solutions that are almost right, but not qu...
# 49084       Debugging AI-generated code is more time-consu...
# 49085                      I haven’t encountered any problems
# 49089                                                     NaN
#
#                                                     AIExplain  \
# ResponseId
# 2                                                          No
# 6                                                  No it isnt
# 8                                                         Yes
# 23          No. I find it to be useless, unless I'm starti...
# 26          Sometimes. But rarely for important profession...
# ...                                                       ...
# 49067       No, I don't write enough new code at the momen...
# 49076                                                     NaN
# 49084                                                     NaN
# 49085                                              It is not.
# 49089                                                     NaN
#
#                                                      AIAgents  \
# ResponseId
# 2                                     No, and I don't plan to
# 6           Yes, I use AI agents at work monthly or infreq...
# 8                                           No, but I plan to
# 23                                    No, and I don't plan to
# 26                        Yes, I use AI agents at work weekly
# ...                                                       ...
# 49067       Yes, I use AI agents at work monthly or infreq...
# 49076                                                     NaN
# 49084                                       No, but I plan to
# 49085                                       No, but I plan to
# 49089                                                     NaN
#
#                       AIAgentChange  \
# ResponseId
# 2           Not at all or minimally
# 6           Not at all or minimally
# 8            Yes, to a great extent
# 23          Not at all or minimally
# 26                    Yes, somewhat
# ...                             ...
# 49067                 Yes, somewhat
# 49076                           NaN
# 49084                           NaN
# 49085       Not at all or minimally
# 49089                           NaN
#
#                                                  AIAgent_Uses  \
# ResponseId
# 2                                                         NaN
# 6           Software engineering;Business process automati...
# 8                                                         NaN
# 23                                                        NaN
# 26                             Software engineering;Marketing
# ...                                                       ...
# 49067                                                     NaN
# 49076                                                     NaN
# 49084                                                     NaN
# 49085                                                     NaN
# 49089                                                     NaN
#
#                                      AgentUsesGeneral  \
# ResponseId
# 2                                                 NaN
# 6                                                 NaN
# 8                                                 NaN
# 23                                                NaN
# 26          Integration with external agents and APIs
# ...                                               ...
# 49067                                             NaN
# 49076                                             NaN
# 49084                                             NaN
# 49085                                             NaN
# 49089                                             NaN
#
#                                   AIAgentImpactSomewhat agree  \
# ResponseId
# 2                                                         NaN
# 6           AI agents have increased my productivity.;AI a...
# 8                                                         NaN
# 23                                                        NaN
# 26          AI agents have increased my productivity.;AI a...
# ...                                                       ...
# 49067                                                     NaN
# 49076                                                     NaN
# 49084                                                     NaN
# 49085                                                     NaN
# 49089                                                     NaN
#
#                                          AIAgentImpactNeutral  \
# ResponseId
# 2                                                         NaN
# 6                                                         NaN
# 8                                                         NaN
# 23                                                        NaN
# 26          AI agents have improved the quality of my code...
# ...                                                       ...
# 49067                                                     NaN
# 49076                                                     NaN
# 49084                                                     NaN
# 49085                                                     NaN
# 49089                                                     NaN
#
#                                AIAgentImpactSomewhat disagree  \
# ResponseId
# 2                                                         NaN
# 6           AI agents have improved the quality of my code...
# 8                                                         NaN
# 23                                                        NaN
# 26                                                        NaN
# ...                                                       ...
# 49067                                                     NaN
# 49076                                                     NaN
# 49084                                                     NaN
# 49085                                                     NaN
# 49089                                                     NaN
#
#                                   AIAgentImpactStrongly agree  \
# ResponseId
# 2                                                         NaN
# 6           AI agents have helped me automate repetitive t...
# 8                                                         NaN
# 23                                                        NaN
# 26          AI agents have helped me automate repetitive t...
# ...                                                       ...
# 49067                                                     NaN
# 49076                                                     NaN
# 49084                                                     NaN
# 49085                                                     NaN
# 49089                                                     NaN
#
#            AIAgentImpactStrongly disagree  \
# ResponseId
# 2                                     NaN
# 6                                     NaN
# 8                                     NaN
# 23                                    NaN
# 26                                    NaN
# ...                                   ...
# 49067                                 NaN
# 49076                                 NaN
# 49084                                 NaN
# 49085                                 NaN
# 49089                                 NaN
#
#                                      AIAgentChallengesNeutral  \
# ResponseId
# 2           It takes significant time and effort to learn ...
# 6           The cost of using certain AI agent platforms i...
# 8                                                         NaN
# 23          It takes significant time and effort to learn ...
# 26          Integrating AI agents with my existing tools a...
# ...                                                       ...
# 49067                                                     NaN
# 49076                                                     NaN
# 49084                                                     NaN
# 49085                                                     NaN
# 49089                                                     NaN
#
#                            AIAgentChallengesSomewhat disagree  \
# ResponseId
# 2                                                         NaN
# 6                                                         NaN
# 8           I have concerns about the security and privacy...
# 23                                                        NaN
# 26          It takes significant time and effort to learn ...
# ...                                                       ...
# 49067                                                     NaN
# 49076                                                     NaN
# 49084                                                     NaN
# 49085                                                     NaN
# 49089                                                     NaN
#
#                               AIAgentChallengesStrongly agree  \
# ResponseId
# 2           I am concerned about the accuracy of the infor...
# 6           I am concerned about the accuracy of the infor...
# 8           I am concerned about the accuracy of the infor...
# 23                                                        NaN
# 26                                                        NaN
# ...                                                       ...
# 49067                                                     NaN
# 49076                                                     NaN
# 49084                                                     NaN
# 49085                                                     NaN
# 49089                                                     NaN
#
#                               AIAgentChallengesSomewhat agree  \
# ResponseId
# 2           Integrating AI agents with my existing tools a...
# 6           Integrating AI agents with my existing tools a...
# 8           The cost of using certain AI agent platforms i...
# 23          I am concerned about the accuracy of the infor...
# 26          I am concerned about the accuracy of the infor...
# ...                                                       ...
# 49067                                                     NaN
# 49076                                                     NaN
# 49084                                                     NaN
# 49085                                                     NaN
# 49089                                                     NaN
#
#                            AIAgentChallengesStrongly disagree  \
# ResponseId
# 2                                                         NaN
# 6           My company's IT and/or InfoSec teams have stri...
# 8           Integrating AI agents with my existing tools a...
# 23          My company's IT and/or InfoSec teams have stri...
# 26                                                        NaN
# ...                                                       ...
# 49067                                                     NaN
# 49076                                                     NaN
# 49084                                                     NaN
# 49085                                                     NaN
# 49089                                                     NaN
#
#            AIAgentKnowledge AIAgentKnowWrite AIAgentOrchestration  \
# ResponseId
# 2                       NaN              NaN                  NaN
# 6                       NaN              NaN                  NaN
# 8                       NaN              NaN                  NaN
# 23                      NaN              NaN                  NaN
# 26                      NaN              NaN                  NaN
# ...                     ...              ...                  ...
# 49067                   NaN              NaN                  NaN
# 49076                   NaN              NaN                  NaN
# 49084                   NaN              NaN                  NaN
# 49085                   NaN              NaN                  NaN
# 49089                   NaN              NaN                  NaN
#
#            AIAgentOrchWrite AIAgentObserveSecure AIAgentObsWrite  \
# ResponseId
# 2                       NaN                  NaN             NaN
# 6                       NaN                  NaN             NaN
# 8                       NaN                  NaN             NaN
# 23                      NaN                  NaN             NaN
# 26                      NaN                  NaN             NaN
# ...                     ...                  ...             ...
# 49067                   NaN                  NaN             NaN
# 49076                   NaN                  NaN             NaN
# 49084                   NaN                  NaN             NaN
# 49085                   NaN                  NaN             NaN
# 49089                   NaN                  NaN             NaN
#
#                           AIAgentExternal AIAgentExtWrite  \
# ResponseId
# 2                                     NaN             NaN
# 6                          GitHub Copilot             NaN
# 8                                     NaN             NaN
# 23                                    NaN             NaN
# 26          ChatGPT;GitHub Copilot;Replit             NaN
# ...                                   ...             ...
# 49067                                 NaN             NaN
# 49076                                 NaN             NaN
# 49084                                 NaN             NaN
# 49085                                 NaN             NaN
# 49089                                 NaN             NaN
#
#                                                       AIHuman  \
# ResponseId
# 2           When I don’t trust AI’s answers;When I want to...
# 6           When I have ethical or security concerns about...
# 8           When I want to learn best practices;When I wan...
# 23          When I don’t trust AI’s answers;When I want to...
# 26          When I don’t trust AI’s answers;When I want to...
# ...                                                       ...
# 49067                                                     NaN
# 49076                                                     NaN
# 49084                                                     NaN
# 49085                                                     NaN
# 49089                                                     NaN
#
#                                                        AIOpen  \
# ResponseId
# 2                                   All skills. AI is a flop.
# 6                designing the architecture in the new domain
# 8                                   Innovation, system design
# 23          Technical knowledge. As AI slides into the for...
# 26          Choosing the best solutions. Converting user r...
# ...                                                       ...
# 49067                                                     NaN
# 49076                                                     NaN
# 49084                                                     NaN
# 49085                                                     NaN
# 49089                                                     NaN
#
#            ConvertedCompYearly JobSat
# ResponseId
# 2                     104413.0    9.0
# 6                     120000.0    7.0
# 8                      72000.0    6.0
# 23                     87500.0    9.0
# 26                    108913.0    8.0
# ...                        ...    ...
# 49067                 138470.0    6.0
# 49076                  82366.0    2.0
# 49084                 188000.0    NaN
# 49085                 119000.0    NaN
# 49089                 280000.0    NaN
#
# [12702 rows x 171 columns]

# %%
df.loc[high_salary, ['Country', 'EdLevel', 'ConvertedCompYearly']]
# Out:
#                                                       Country  \
# ResponseId
# 2                                                 Netherlands
# 6                                                     Ukraine
# 8                                                     Ukraine
# 23                                   United States of America
# 26          United Kingdom of Great Britain and Northern I...
# ...                                                       ...
# 49067                                               Australia
# 49076       United Kingdom of Great Britain and Northern I...
# 49084                                United States of America
# 49085                                United States of America
# 49089                                United States of America
#
#                                                       EdLevel  \
# ResponseId
# 2                         Associate degree (A.A., A.S., etc.)
# 6             Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 8              Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 23          Some college/university study without earning ...
# 26               Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                       ...
# 49067            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 49076         Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 49084            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 49085         Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 49089            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#             ConvertedCompYearly
# ResponseId
# 2                      104413.0
# 6                      120000.0
# 8                       72000.0
# 23                      87500.0
# 26                     108913.0
# ...                         ...
# 49067                  138470.0
# 49076                   82366.0
# 49084                  188000.0
# 49085                  119000.0
# 49089                  280000.0
#
# [12702 rows x 3 columns]

# %%
countries = ['United States', 'India', 'United Kingdom', 'Germany', 'Canada']

# %%
filt = df['Country'].isin(countries)

# %%
df.loc[filt, 'Country']
# Out:
# ResponseId
# 14         India
# 16         India
# 19       Germany
# 36       Germany
# 47         India
#           ...
# 49155      India
# 49156      India
# 49176    Germany
# 49179    Germany
# 49181     Canada
# Name: Country, Length: 6877, dtype: str

# %%
df['EdLevel']
# Out:
# ResponseId
# 1          Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 2                      Associate degree (A.A., A.S., etc.)
# 3             Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4             Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 5          Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#                                ...
# 49187         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 49188    Some college/university study without earning ...
# 49189      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 49190       Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 49191    Some college/university study without earning ...
# Name: EdLevel, Length: 49191, dtype: str

# %%
filt = df['EdLevel'].str.contains('Master', na=False)

# %%
filt
# Out:
# ResponseId
# 1         True
# 2        False
# 3        False
# 4        False
# 5         True
#          ...
# 49187    False
# 49188    False
# 49189     True
# 49190    False
# 49191    False
# Name: EdLevel, Length: 49191, dtype: bool

# %%
df.loc[filt, 'EdLevel']
# Out:
# ResponseId
# 1        Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 5        Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 6        Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 10       Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 11       Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#                               ...
# 49162    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 49167    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 49176    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 49184    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 49189    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# Name: EdLevel, Length: 12589, dtype: str
